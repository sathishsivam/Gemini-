# %% [markdown]
# <a href="https://colab.research.google.com/github/sathishsivam/Gemini-/blob/main/GenAI_apex_gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyD64bKRXiINVbwHaKb2-L5Krkjt5M6Kq6Q")

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# ...

# %%
model=genai.GenerativeModel("gemini-pro")

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
res=model.generate_content("what is ARPANET")

# %%
print(res.text)
# Out:
# That's a photo of a large lecture or presentation hall.  A man in a white shirt is speaking into a microphone to a sizable audience. The audience is predominantly young adults, mostly men, seated in rows of chairs.
#
#
# The setting appears to be a formal or educational environment, possibly a university auditorium or conference room. The overall mood seems attentive and engaged, suggesting the speaker is holding the audience's interest.  A camera on a tripod is visible near the front, indicating the event may be recorded.

# %%
vision_model=genai.GenerativeModel("gemini-1.5-flash")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image
img=Image.open("/content/sathish.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=799x200>

# %%
res=vision_model.generate_content(["exaplain this image",img])

# %%
print(res.text)
# Out:
# That's a photo of a large group of people attending a lecture or presentation.
#
#
# Here's a breakdown:
#
# * **The Speaker:** A man in a light-colored, long-sleeved shirt is prominently featured on the left, holding a microphone. He appears to be giving a talk or presentation.
#
# * **The Audience:** A large audience, predominantly young adults, fills a lecture hall or auditorium. They are seated in rows of chairs. The audience appears to be engaged and attentive. Many are looking towards the speaker.
#
# * **The Setting:** The venue looks like a modern auditorium or conference hall with tiered seating.  The lighting suggests it's indoors.
#
# * **Overall Impression:** The image conveys a sense of a formal event, possibly a seminar, workshop, or lecture, where a speaker is addressing a large, interested audience. The attire of the audience suggests a somewhat formal or professional setting.

# %%
vision_model1=genai.GenerativeModel("gemini-1.5-flash")

# %%
vision_model1.generate_content(["In which country the sales is low in this image ",Image.open("/content/bar-charts-466x300.jpg")])
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "Based on the provided bar chart, **Mexico** had the lowest sales among the top 5 countries."
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.09383452506292433
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 270,
#         "candidates_token_count": 21,
#         "total_token_count": 291
#       }
#     }),
# )

# %%
text_img=Image.open("/content/IvV2y.png")

# %%
text_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=700x440>

# %%
model_text=genai.GenerativeModel("gemini-1.5-flash")

# %%
print(model_text.generate_content(["Extract the text from this image",text_img]).text)
# Out:
# It was the best of
# times, it was the worst
# of times, it was the age
# of wisdom, it was the
# age of foolishness...

# %%
()
